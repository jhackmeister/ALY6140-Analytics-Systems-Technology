# %%
#Import necessary libraries
import pandas as pd
import numpy as np
import json

# %%
#Import necessary libraries
import pandas as pd
import numpy as np
import json

"""
<ALY 6140 Module 2 Assignnment>


Copyright (c) 2021 -- This is the 2021 Spring B version of the Template
Licensed
Written by <Jeff Hackmeister>

# you can also rely on the docstring documentation from pandas on how to format dosctrings:
# https://pandas.pydata.org/pandas-docs/stable/development/contributing_docstring.html

"""

def import_csv(path):
    """
    :Import csv file from direct path to personal directory
    :read csv file with the head function
    """
    pd.read_csv(path, sep=',', header=0, encoding='utf-8')
    return csv_data

def import_text(path):
    """
    :Import txt sv file from direct path to personal directory
    :Open function, read mode ('r'), and utf-8 encoder used to import text file.
    :return: the encoded text file
    """
    with open(path, 'r', encoding='utf-8') as file:
        text_data = file.readlines()
    return text_data

def import_json(path):
    """
    :Import json fsv file from direct path to personal directory
    :Open function, read mode ('r'), and utf-8 encoder used to import json file.
    :return: the encoded json file
    """
    with open(path, 'r', encoding='utf-8') as file:
        json_data = json.load(file)
    return json_data

def import_excel(path):
    """
    :Import xlsx sv file from direct path to personal directory
    :Read excel file and specified sheet name with the head function.
    """
    pd.read_excel(path, sheet_name=0, header=0, engine='openpyxl')
    return excel_data
    
if __name__ == '__main__':
    csv_data = import_csv(r'C:\Users\jhack\OneDrive\Northeastern\ALY6140 - Analytics Systems Technology (Python)\Module2\Neural_data.csv')
    text_data = import_text(r'C:\Users\jhack\OneDrive\Northeastern\ALY6140 - Analytics Systems Technology (Python)\Module2\network_data/txy')
    json_data = import_json('r'C:\Users\jhack\OneDrive\Northeastern\ALY6140 - Analytics Systems Technology (Python)\Module2\nested_data.json')
    excel_data = import_excel(r'C:\Users\jhack\OneDrive\Northeastern\ALY6140 - Analytics Systems Technology (Python)\Module2\Excel_report.xlsx')

    csv_data = import_csv(csv_file_path)
    text_data = import_text(text_file_path)
    json_data = import_json(json_file_path)
    excel_data = import_excel(excel_file_path)
